# %%
import pandas as pd

# %%
url = './data-maxtemp/timeseries-data/jma-maxtemp-heatpoints-by-pref-yearly.csv'

# %%
df = pd.read_csv(url)

# %%
df[df.pref=='大阪府']
# Out:
#       year pref  over30  over30_capitol  over35  over35_capitol  over40
# 26    2000  大阪府      89              85      31              26       0  \
# 73    2001  大阪府      78              77      29              21       0
# 120   2002  大阪府      89              86      28              22       0
# 167   2003  大阪府      72              66      11               7       0
# 214   2004  大阪府     103              94      26              20       0
# 261   2005  大阪府     102              88      23               8       0
# 308   2006  大阪府      78              71      27              17       0
# 355   2007  大阪府      83              79      21              16       0
# 402   2008  大阪府      84              71      24              13       0
# 449   2009  大阪府      86              73       9               3       0
# 496   2010  大阪府      94              82      40              31       0
# 543   2011  大阪府      82              76      27               7       0
# ...

# %%
df.groupby(['year'])[['over35','over35_capitol']].sum()

# %%
df.groupby(['year'])[['over35','over35_capitol']].sum()
# Out:
#       over35  over35_capitol
# year
# 2000     678             391
# 2001     734             438
# 2002     661             379
# 2003     349             109
# 2004     789             369
# 2005     602             227
# 2006     690             299
# 2007     722             349
# 2008     785             351
# 2009     246              84
# 2010    1358             687
# 2011     739             298
# 2012     877             396
# 2013    1109             591
# 2014     439             215
# 2015     691             358
# 2016     849             409
# 2017     657             291
# 2018    1406             792
# 2019     817             419
# 2020    1017             578
# 2021     682             309
# 2022    1055             500
# 2023     922             517

# %%
df.groupby(['year'])[['over40','over40_capitol']].sum()
# Out:
#       over40  over40_capitol
# year
# 2000       0               0
# 2001       2               1
# 2002       0               0
# 2003       0               0
# 2004       2               1
# 2005       0               0
# 2006       0               0
# 2007       5               0
# 2008       0               0
# 2009       0               0
# 2010       0               0
# 2011       0               0
# 2012       0               0
# 2013       7               2
# 2014       0               0
# 2015       0               0
# 2016       0               0
# 2017       0               0
# 2018      11               2
# 2019       4               0
# 2020       5               0
# 2021       1               0
# 2022       6               0
# 2023       1               0

# %%
df[df.over40==1]
# Out:
#       year pref  over30  over30_capitol  over35  over35_capitol  over40
# 56    2001  群馬県      57              52      16              15       1  \
# 63    2001  静岡県      81              54      18               5       1
# 200   2004  千葉県      86              68      18               3       1
# 203   2004  山梨県      95              86      18              17       1
# 339   2007  埼玉県      72              54      21               8       1
# 620   2013  群馬県      83              67      26              17       1
# 856   2018  埼玉県      84              70      40              23       1
# 857   2018  東京都     170              68      30              12       1
# 861   2018  山梨県      96              86      37              31       1
# 863   2018  愛知県      86              80      37              36       1
# 866   2018  新潟県      71              49      24               4       1
# 898   2019  山形県      56              43      14              11       1
# ...
